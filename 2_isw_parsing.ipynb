# %%
import pandas as pd
from IPython.core.display import display, HTML
from bs4 import BeautifulSoup
# Out:
# C:\Users\justf\AppData\Local\Temp\ipykernel_7968\3737384758.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
INPUT_DATA_FOLDER = '1_isw_prepared'
DATA_FILE = 'isw_all_days.csv'
OUTPUT_FOLDER = '2_isw_parsed'
OUTPUT_DATA_FILE = 'isw_all_days_parsed.csv'

# %%
df = pd.read_csv(f'{INPUT_DATA_FOLDER}/{DATA_FILE}', sep=';')

# %%
df.head()
# Out:
#          date                                          short_url  \
# 0  2022-02-24  russia_ukraine_warning_update_initial_russian_...
# 1  2022-02-25  russia_ukraine_warning_update_russian_offensiv...
# 2  2022-02-27  russia_ukraine_warning_update_russian_offensiv...
# 3  2022-02-28  russian_offensive_campaign_assessment_february...
# 4  2022-03-01      russian_offensive_campaign_assessment_march_1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# ...

# %%
test_row = df.iloc[10]
page_html_text = test_row['main_html']
print(page_html_text)
# Out:
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded"> <p align="center" style="text-align: left;"> </p>
# <p align="center" style="text-align: left;"><strong>Fredrick W. Kagan, George Barros, and Kateryna Stepanenko</strong></p>
# <p align="center" style="text-align: left;"><strong>March 7, 3:00 PM EST</strong></p>
# ...

# %%
display(HTML(page_html_text))
# Out:
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded"> <p align="center" style="text-align: left;"> </p>
# <p align="center" style="text-align: left;"><strong>Fredrick W. Kagan, George Barros, and Kateryna Stepanenko</strong></p>
# <p align="center" style="text-align: left;"><strong>March 7, 3:00 PM EST</strong></p>
# ...

# %%
def remove_names_and_dates(page_html_text):
    parsed_html = BeautifulSoup(page_html_text)
    p_lines = parsed_html.findAll('p')
    
    min_sentences_word_count = 20
    p_index=0
    
    for p_line in p_lines:
        strong_lines = p_line.findAll('strong')
        if not strong_lines:
            continue
            
        for s in strong_lines:
            if len(s.text.split(' '))>= min_sentences_word_count:
                break
        else:
            p_index +=1
            continue
        break
    for i in range(0, p_index):
        page_html_text = page_html_text.replace(str(p_lines[i]), '')
    return page_html_text

# %%
df['main_html_v2'] = df['main_html'].apply(lambda x: remove_names_and_dates(x))

# %%
df.head()
# Out:
#          date                                          short_url  \
# 0  2022-02-24  russia_ukraine_warning_update_initial_russian_...
# 1  2022-02-25  russia_ukraine_warning_update_russian_offensiv...
# 2  2022-02-27  russia_ukraine_warning_update_russian_offensiv...
# 3  2022-02-28  russian_offensive_campaign_assessment_february...
# 4  2022-03-01      russian_offensive_campaign_assessment_march_1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# ...

# %%
test_row = df.iloc[10]
page_html_text_v2 = test_row['main_html_v2']

# %%
display(HTML(page_html_text_v2))
# Out:
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded">
#
# <p align="center" style="text-align: left;"><strong>March 7, 3:00 PM EST</strong></p>
# ...

# %%
df['main_html_v3'] = df['main_html_v2'].apply(lambda x: remove_names_and_dates(x))

# %%
test_row = df.iloc[10]
page_html_text_v3 = test_row['main_html_v3']

# %%
display(HTML(page_html_text_v3))
# Out:
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded">
#
#
# ...

# %%
df.head()
# Out:
#          date                                          short_url  \
# 0  2022-02-24  russia_ukraine_warning_update_initial_russian_...
# 1  2022-02-25  russia_ukraine_warning_update_russian_offensiv...
# 2  2022-02-27  russia_ukraine_warning_update_russian_offensiv...
# 3  2022-02-28  russian_offensive_campaign_assessment_february...
# 4  2022-03-01      russian_offensive_campaign_assessment_march_1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# ...

# %%
import re

pattern = '\[(\d+)\]'

df['main_html_v4'] = df['main_html_v3'].apply(lambda x: re.sub(pattern, '', x))

# %%
test_row = df.iloc[10]
page_html_text_v4 = test_row['main_html_v4']
display(HTML(page_html_text_v4))

# %%
df['main_html_v5'] = df['main_html_v4'].apply(lambda x: BeautifulSoup(x).text)

# %%
df.head(10)

# %%
df['main_html_v6'] = df['main_html_v5'].apply(lambda x: re.sub(r'http(\S+.*\s)','',x))
df['main_html_v7'] = df['main_html_v6'].apply(lambda x: re.sub(r'(o2022|o2023|2022|2023)','',x))

# %%
test_row = df.iloc[10]
page_html_text_v7 = test_row['main_html_v7']
display(HTML(page_html_text_v7))
# Out:
# Russian forces are concentrating in the eastern, northwestern, and western outskirts of Kyiv for an assault on the capital in the coming 24-96 hours. The Russians are bringing up supplies and reinforcements as well as conducting artillery, air, and missile attacks to weaken defenses and intimidate defenders in advance of such an assault. It is too soon to gauge the likely effectiveness of any Russian attempt to complete the encirclement of Kyiv or to seize the city at this time. If Russian troops have been able to resupply, reorganize, and plan deliberate and coordinated simultaneous operations along the several axes of advance around and into the capital, they may be more successful in this operation than they have in previous undertakings. Operations near Kyiv in the past 72 hours have not offered enough evidence to evaluate that likelihood.
# ...

# %%
df.head()
# Out:
#          date                                          short_url  \
# 0  2022-02-24  russia_ukraine_warning_update_initial_russian_...
# 1  2022-02-25  russia_ukraine_warning_update_russian_offensiv...
# 2  2022-02-27  russia_ukraine_warning_update_russian_offensiv...
# 3  2022-02-28  russian_offensive_campaign_assessment_february...
# 4  2022-03-01      russian_offensive_campaign_assessment_march_1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# ...

# %%
df['main_html_v2'] = df['main_html'].apply(lambda x: BeautifulSoup(x).text)
df2 = df.drop(['main_html_v2','main_html_v3','main_html_v4',
               'main_html_v5', 'main_html_v6'], axis = 1)

# %%
df2.to_csv(f'{OUTPUT_FOLDER}/{OUTPUT_DATA_FILE}', sep =';', index = False)
